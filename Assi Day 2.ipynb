# %%
#Day 2 assignment
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline

# %%
#Name-karan girish rane

# %%
from numpy.random import randn,randint
x = pd.DataFrame(randn(10,4),columns=['a','b','c','d'])
x
# Out:
#           a         b         c         d
# 0  0.480764 -1.069659 -0.616755  1.673396
# 1 -1.469616 -0.116058  1.018331  2.060384
# 2 -0.716764  0.592546 -1.495365  0.630663
# 3  1.342816  1.089751  0.388439 -2.103320
# 4 -1.459076  0.935639  0.796809  0.301968
# 5 -0.169874 -1.461662 -1.939567 -1.635836
# 6 -0.753836 -1.125078 -0.113050 -1.356731
# 7 -0.291790  0.863173  0.415653  0.813582
# 8  0.139885 -0.248668  1.573615  0.784823
# 9  2.876421  0.683709  0.039023 -1.699125

# %%
x.plot(kind='bar',color=('r','b','orange','black'),figsize=(50,50))
plt.title("bar plot")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
